# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('books.csv')
users = pd.read_csv('users.csv')
ratings = pd.read_csv('ratings.csv')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10636\3819754567.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('books.csv')

# %%
books.head()
# Out:
#         ISBN                                         Book-Title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Popularity Based Recommender System

# %%
ratings_with_names = ratings.merge(books,on='ISBN')

# %%
num_rating_df = ratings_with_names.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                               Book-Title  num_ratings
# 0       Earth Prayers From around the World: 365 Pray...           10
# 1       Final Fantasy Anthology: Official Strategy Gu...            4
# 2       Flight of Fancy: American Heiresses (Zebra Ba...            2
# 3       Little Comic Shop of Horrors (Give Yourself G...            4
# 4                                           Mystery Mile            2
# ...                                                  ...          ...
# 68750                                      Ã?Â?lpiraten.            2
# 68751                     Ã?Â?rger mit Produkt X. Roman.            4
# 68752                                Ã?Â?sterlich leben.            1
# 68753                              Ã?Â?stlich der Berge.            3
# 68754                                  Ã?Â?thique en toc            2
#
# [68755 rows x 2 columns]

# %%
avg_rating_df = ratings_with_names.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                               Book-Title  avg_rating
# 0       Earth Prayers From around the World: 365 Pray...    5.000000
# 1       Final Fantasy Anthology: Official Strategy Gu...    5.000000
# 2       Flight of Fancy: American Heiresses (Zebra Ba...    4.000000
# 3       Little Comic Shop of Horrors (Give Yourself G...    1.250000
# 4                                           Mystery Mile    0.000000
# ...                                                  ...         ...
# 68750                                      Ã?Â?lpiraten.    0.000000
# 68751                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 68752                                Ã?Â?sterlich leben.    7.000000
# 68753                              Ã?Â?stlich der Berge.    2.666667
# 68754                                  Ã?Â?thique en toc    4.000000
#
# [68755 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                               Book-Title  num_ratings  \
# 0       Earth Prayers From around the World: 365 Pray...           10
# 1       Final Fantasy Anthology: Official Strategy Gu...            4
# 2       Flight of Fancy: American Heiresses (Zebra Ba...            2
# 3       Little Comic Shop of Horrors (Give Yourself G...            4
# 4                                           Mystery Mile            2
# ...                                                  ...          ...
# 68750                                      Ã?Â?lpiraten.            2
# 68751                     Ã?Â?rger mit Produkt X. Roman.            4
# 68752                                Ã?Â?sterlich leben.            1
# 68753                              Ã?Â?stlich der Berge.            3
# 68754                                  Ã?Â?thique en toc            2
#
#        avg_rating
# 0        5.000000
# 1        5.000000
# 2        4.000000
# 3        1.250000
# 4        0.000000
# ...           ...
# 68750    0.000000
# 68751    5.250000
# 68752    7.000000
# 68753    2.666667
# 68754    4.000000
#
# [68755 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(10)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-S','num_ratings','avg_rating']]

# %%
popular_df
# Out:
#                                            Book-Title             Book-Author  \
# 0   Harry Potter and the Order of the Phoenix (Boo...           J. K. Rowling
# 4   Harry Potter and the Sorcerer's Stone (Harry P...           J. K. Rowling
# 6   A Child Called \It\": One Child's Courage to S...             Dave Pelzer
# 8                               Bridget Jones's Diary          Helen Fielding
# 14  The No. 1 Ladies' Detective Agency (Today Show...  Alexander McCall Smith
# 15                                     How to Be Good             Nick Hornby
# 18                             Snow Falling on Cedars          David Guterson
# 25                                    A Painted House            John Grisham
# 30                      The Bridges of Madison County     Robert James Waller
# 35                                           The Firm            John Grisham
#
#                                           Image-URL-S  num_ratings  avg_rating
# 0   http://images.amazon.com/images/P/043935806X.0...          335    5.585075
# 4   http://images.amazon.com/images/P/059035342X.0...          575    4.895652
# 6   http://images.amazon.com/images/P/1558743669.0...          265    4.086792
# 8   http://images.amazon.com/images/P/0330332775.0...          270    3.751852
# 14  http://images.amazon.com/images/P/1400034779.0...          431    3.417633
# 15  http://images.amazon.com/images/P/1573229326.0...          304    3.305921
# 18  http://images.amazon.com/images/P/0151001006.0...          627    3.236045
# 25  http://images.amazon.com/images/P/044023722X.0...          833    3.222089
# 30  http://images.amazon.com/images/P/044651652X.0...          371    3.097035
# 35  http://images.amazon.com/images/P/0385416342.0...          535    3.063551

# %% [markdown]
# # Collaborative Filtering Based Recommender System

# %%
x = ratings_with_names.groupby('User-ID').count()['Book-Rating'] >200
genuine_users = x[x].index

# %%
filtered_rating = ratings_with_names[ratings_with_names['User-ID'].isin(genuine_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=10
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             11601   11676   16795   \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0    10.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     9.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0    10.0     0.0
# White Mountain                                         0.0     0.0     5.0
#
# User-ID                                             23768   23902   26544   \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     8.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# User-ID                                             35859   36606   36836   \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               8.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# User-ID                                             52584   ...  232131  \
# Book-Title                                                  ...
# 16 Lighthouse Road                                     0.0  ...     0.0
# 204 Rosewood Lane                                      0.0  ...     0.0
# 311 Pelican Court                                      0.0  ...     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0  ...     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0  ...     0.0
# Up Island: A Novel                                     0.0  ...     0.0
# Welcome to the World, Baby Girl!                       0.0  ...     0.0
# What Looks Like Crazy On An Ordinary Day               9.0  ...     0.0
# White Mountain                                         0.0  ...     0.0
#
# User-ID                                             234623  235105  238781  \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# User-ID                                             242824  245963  261105  \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# User-ID                                             266226  275970  278418
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# [128 rows x 63 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (128, 128)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse = True)[1:15]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('Undead and Unwed (Berkley Sensation)')
# Out:
# [['Getting Lucky (Avon Light Contemporary Romances)',
#   'Susan Andersen',
#   'http://images.amazon.com/images/P/038081918X.01.MZZZZZZZ.jpg'],
#  ['Beach House',
#   'Mary Alice Monroe',
#   'http://images.amazon.com/images/P/1551668998.01.MZZZZZZZ.jpg'],
#  ['Cold Ridge',
#   'Carla Neggers',
#   'http://images.amazon.com/images/P/1551666847.01.MZZZZZZZ.jpg'],
#  ['Dead Run',
#   'Erica Spindler',
#   'http://images.amazon.com/images/P/1551666839.01.MZZZZZZZ.jpg'],
#  ['Enchanted Afternoon',
#   'Susan Wiggs',
#   'http://images.amazon.com/images/P/1551669382.01.MZZZZZZZ.jpg'],
#  ["Full Tilt (Janet Evanovich's Full Series)",
#   'Janet Evanovich',
#   'http://images.amazon.com/images/P/031298328X.01.MZZZZZZZ.jpg'],
#  ['Haunted',
#   'Heather Graham',
#   'http://images.amazon.com/images/P/1551667509.01.MZZZZZZZ.jpg'],
#  ['Letting Go',
#   'Pamela Morsi',
#   'http://images.amazon.com/images/P/1551666561.01.MZZZZZZZ.jpg'],
#  ['Like Silk',
#   'Mary Lynn Baxter',
#   'http://images.amazon.com/images/P/1551669021.01.MZZZZZZZ.jpg'],
#  ['Hurricane Bay',
#   'Heather Graham',
#   'http://images.amazon.com/images/P/1551666650.01.MZZZZZZZ.jpg'],
#  ['White Mountain',
#   'Dinah Mccall',
#   'http://images.amazon.com/images/P/1551668947.01.MZZZZZZZ.jpg'],
#  ['Hot Shot',
#   'Charlotte Hughes',
#   'http://images.amazon.com/images/P/1551669412.01.MZZZZZZZ.jpg'],
#  ['Night Of The Black Bird',
#   'Heather Graham',
#   'http://images.amazon.com/images/P/1551668122.01.MZZZZZZZ.jpg'],
#  ['High Maintenance',
#   'Jennifer Belle',
#   'http://images.amazon.com/images/P/157322930X.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354   449906736      Flashpoints: Promise and Peril in a New World
# 271356   525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358   192126040                        Republic (World's Classics)
# 271359   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271354          Robin Wright                1993
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271354                                  Ballantine Books
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [242131 rows x 8 columns]

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))
